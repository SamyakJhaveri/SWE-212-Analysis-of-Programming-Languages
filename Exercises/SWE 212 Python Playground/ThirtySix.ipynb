# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import sys, os, string, random

characters = string.printable
char_indices = dict((c, i) for i, c in enumerate(characters))
indices_char = dict((i, c) for i, c in enumerate(characters))

INPUT_VOCAB_SIZE = len(characters)
BATCH_SIZE = 200

def encode_one_hot(line):
    x = np.zeros((len(line), INPUT_VOCAB_SIZE))
    for i, c in enumerate(line):
        if c in characters:
            index = char_indices[c]
        else:
            index = char_indices[' ']
        x[i][index] = 1 
    return x

def decode_one_hot(x):
    s = []
    for onehot in x:
        one_index = np.argmax(onehot) 
        s.append(indices_char[one_index]) 
    return ''.join(s)
    
def build_model():
    # Normalize characters using a dense layer
    model = Sequential()
    dense_layer = Dense(INPUT_VOCAB_SIZE, 
                        input_shape=(INPUT_VOCAB_SIZE,),
                        activation='softmax')
    model.add(dense_layer)
    return model

def input_generator(nsamples):
    def generate_line():
        inline = []; outline = []
        leet_map = {'a':'4', 'b':'8', 'c':'<', 'd':')', 'e':'3', 'f':'f', 'g':'6', 
                'h':'#', 'i':'|', 'j':']', 'k':'k', 'l':'1', 'm':'m', 'n':'^',
                'o':'0', 'p':'9', 'q':'&', 'r':'r', 's':'5', 't':'+', 'u':'u',
                'v':'v', 'w':'w', 'x':'x', 'y':'y', 'z':'7'}
        for _ in range(nsamples):
            c = random.choice(characters) 
            expected = c.lower() if c in string.ascii_letters else ' ' 
            leet_expected = leet_map[expected] if expected in leet_map else expected
            inline.append(c); outline.append(leet_expected)
        return ''.join(inline), ''.join(outline)

    while True:
        input_data, l_expected = generate_line()
        data_in = encode_one_hot(input_data)
        data_out = encode_one_hot(l_expected)
        yield data_in, data_out

def train(model):
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    input_gen = input_generator(BATCH_SIZE)
    validation_gen = input_generator(BATCH_SIZE)
    model.fit_generator(input_gen,
                epochs = 50, workers=1,
                steps_per_epoch = 20,
                validation_data = validation_gen,
                validation_steps = 10)

model = build_model()
model.summary()
train(model)

input("Network has been trained. Press <Enter> to run program.")
fp = '../pride-and-prejudice.txt'
# sys.argv[1]
count = 0
with open(fp) as f:
    for line in f:
        if line.isspace(): continue
        batch = encode_one_hot(line)
        preds = model.predict(batch)
        normal = decode_one_hot(preds)
        print(normal)
        count += 1
print("Count:", count)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 100)               10100
#
# =================================================================
# Total params: 10,100
# Trainable params: 10,100
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  1/20 [>.............................] - ETA: 3s - loss: 4.6502 - accuracy: 0.0000e+00
# /var/folders/lx/pk8l0jrj46s2mmm8c8m38p1m0000gn/T/ipykernel_75817/79438774.py:65: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(input_gen,
# 2022-05-28 17:45:20.108215: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 20/20 [==============================] - 0s 14ms/step - loss: 4.6098 - accuracy: 0.0505 - val_loss: 4.5770 - val_accuracy: 0.1045
# Epoch 2/50
# 15/20 [=====================>........] - ETA: 0s - loss: 4.5583 - accuracy: 0.1237
# 2022-05-28 17:45:20.347206: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 20/20 [==============================] - 0s 11ms/step - loss: 4.5524 - accuracy: 0.1350 - val_loss: 4.5227 - val_accuracy: 0.1760
# Epoch 3/50
# 20/20 [==============================] - 0s 11ms/step - loss: 4.4955 - accuracy: 0.1978 - val_loss: 4.4588 - val_accuracy: 0.2480
# Epoch 4/50
# 20/20 [==============================] - 0s 9ms/step - loss: 4.4333 - accuracy: 0.2968 - val_loss: 4.4030 - val_accuracy: 0.3620
# Epoch 5/50
# 20/20 [==============================] - 0s 10ms/step - loss: 4.3792 - accuracy: 0.3793 - val_loss: 4.3460 - val_accuracy: 0.4650
# Epoch 6/50
# 20/20 [==============================] - 0s 11ms/step - loss: 4.3175 - accuracy: 0.5168 - val_loss: 4.2848 - val_accuracy: 0.5765
# Epoch 7/50
# 20/20 [==============================] - 0s 11ms/step - loss: 4.2638 - accuracy: 0.5968 - val_loss: 4.2296 - val_accuracy: 0.6530
# Epoch 8/50
# 20/20 [==============================] - 0s 9ms/step - loss: 4.2025 - accuracy: 0.7048 - val_loss: 4.1706 - val_accuracy: 0.7980
# Epoch 9/50
# 20/20 [==============================] - 0s 10ms/step - loss: 4.1457 - accuracy: 0.8538 - val_loss: 4.1127 - val_accuracy: 0.8985
# Epoch 10/50
# 20/20 [==============================] - 0s 11ms/step - loss: 4.0886 - accuracy: 0.9288 - val_loss: 4.0587 - val_accuracy: 0.9710
# Epoch 11/50
# 20/20 [==============================] - 0s 11ms/step - loss: 4.0314 - accuracy: 0.9793 - val_loss: 3.9991 - val_accuracy: 0.9800
# Epoch 12/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.9782 - accuracy: 0.9878 - val_loss: 3.9513 - val_accuracy: 0.9900
# Epoch 13/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.9216 - accuracy: 0.9920 - val_loss: 3.8935 - val_accuracy: 1.0000
# Epoch 14/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.8677 - accuracy: 1.0000 - val_loss: 3.8362 - val_accuracy: 1.0000
# Epoch 15/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.8150 - accuracy: 1.0000 - val_loss: 3.7843 - val_accuracy: 1.0000
# Epoch 16/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.7568 - accuracy: 1.0000 - val_loss: 3.7286 - val_accuracy: 1.0000
# Epoch 17/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.7036 - accuracy: 1.0000 - val_loss: 3.6713 - val_accuracy: 1.0000
# Epoch 18/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.6506 - accuracy: 1.0000 - val_loss: 3.6226 - val_accuracy: 1.0000
# Epoch 19/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.5941 - accuracy: 1.0000 - val_loss: 3.5725 - val_accuracy: 1.0000
# Epoch 20/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.5496 - accuracy: 1.0000 - val_loss: 3.5205 - val_accuracy: 1.0000
# Epoch 21/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.4939 - accuracy: 1.0000 - val_loss: 3.4590 - val_accuracy: 1.0000
# Epoch 22/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.4415 - accuracy: 1.0000 - val_loss: 3.4155 - val_accuracy: 1.0000
# Epoch 23/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.3882 - accuracy: 1.0000 - val_loss: 3.3593 - val_accuracy: 1.0000
# Epoch 24/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.3345 - accuracy: 1.0000 - val_loss: 3.3106 - val_accuracy: 1.0000
# Epoch 25/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2848 - accuracy: 1.0000 - val_loss: 3.2581 - val_accuracy: 1.0000
# Epoch 26/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.2360 - accuracy: 1.0000 - val_loss: 3.2095 - val_accuracy: 1.0000
# Epoch 27/50
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1878 - accuracy: 1.0000 - val_loss: 3.1579 - val_accuracy: 1.0000
# Epoch 28/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.1341 - accuracy: 1.0000 - val_loss: 3.1149 - val_accuracy: 1.0000
# Epoch 29/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.0863 - accuracy: 1.0000 - val_loss: 3.0623 - val_accuracy: 1.0000
# Epoch 30/50
# 20/20 [==============================] - 0s 11ms/step - loss: 3.0375 - accuracy: 1.0000 - val_loss: 3.0084 - val_accuracy: 1.0000
# Epoch 31/50
# 20/20 [==============================] - 0s 11ms/step - loss: 2.9895 - accuracy: 1.0000 - val_loss: 2.9649 - val_accuracy: 1.0000
# Epoch 32/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.9400 - accuracy: 1.0000 - val_loss: 2.9084 - val_accuracy: 1.0000
# Epoch 33/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.8885 - accuracy: 1.0000 - val_loss: 2.8771 - val_accuracy: 1.0000
# Epoch 34/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.8401 - accuracy: 1.0000 - val_loss: 2.8163 - val_accuracy: 1.0000
# Epoch 35/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.8009 - accuracy: 1.0000 - val_loss: 2.7645 - val_accuracy: 1.0000
# Epoch 36/50
# 20/20 [==============================] - 0s 11ms/step - loss: 2.7548 - accuracy: 1.0000 - val_loss: 2.7244 - val_accuracy: 1.0000
# Epoch 37/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.6980 - accuracy: 1.0000 - val_loss: 2.6830 - val_accuracy: 1.0000
# Epoch 38/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.6504 - accuracy: 1.0000 - val_loss: 2.6359 - val_accuracy: 1.0000
# Epoch 39/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.6146 - accuracy: 1.0000 - val_loss: 2.5828 - val_accuracy: 1.0000
# Epoch 40/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.5641 - accuracy: 1.0000 - val_loss: 2.5408 - val_accuracy: 1.0000
# Epoch 41/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.5172 - accuracy: 1.0000 - val_loss: 2.4898 - val_accuracy: 1.0000
# Epoch 42/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4732 - accuracy: 1.0000 - val_loss: 2.4561 - val_accuracy: 1.0000
# Epoch 43/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.4295 - accuracy: 1.0000 - val_loss: 2.4028 - val_accuracy: 1.0000
# Epoch 44/50
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3880 - accuracy: 1.0000 - val_loss: 2.3549 - val_accuracy: 1.0000
# Epoch 45/50
# 20/20 [==============================] - 0s 9ms/step - loss: 2.3525 - accuracy: 1.0000 - val_loss: 2.3122 - val_accuracy: 1.0000
# Epoch 46/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.3012 - accuracy: 1.0000 - val_loss: 2.2665 - val_accuracy: 1.0000
# Epoch 47/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2554 - accuracy: 1.0000 - val_loss: 2.2343 - val_accuracy: 1.0000
# Epoch 48/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.2234 - accuracy: 1.0000 - val_loss: 2.1941 - val_accuracy: 1.0000
# Epoch 49/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1745 - accuracy: 1.0000 - val_loss: 2.1466 - val_accuracy: 1.0000
# Epoch 50/50
# 20/20 [==============================] - 0s 10ms/step - loss: 2.1366 - accuracy: 1.0000 - val_loss: 2.1102 - val_accuracy: 1.0000
# Network has been trained. Press <Enter> to run program.
# 3/3 [==============================] - 0s 4ms/step
# +#3 9r0]3<+ 6u+3^83r6 3800k 0f 9r|)3 4^) 9r3]u)|<3  8y ]4^3 4u5+3^
# 3/3 [==============================] - 0s 3ms/step
# +#|5 3800k |5 f0r +#3 u53 0f 4^y0^3 4^yw#3r3 4+ ^0 <05+ 4^) w|+#
# 3/3 [==============================] - 0s 3ms/step
# 41m05+ ^0 r35+r|<+|0^5 w#4+503v3r   y0u m4y <09y |+  6|v3 |+ 4w4y 0r
# 3/3 [==============================] - 0s 3ms/step
# r3 u53 |+ u^)3r +#3 +3rm5 0f +#3 9r0]3<+ 6u+3^83r6 1|<3^53 |^<1u)3)
# 2/2 [==============================] - 0s 4ms/step
# w|+# +#|5 3800k 0r 0^1|^3 4+ www 6u+3^83r6 0r6
# 1/1 [==============================] - 0s 10ms/step
# 2022-05-28 17:54:04.362819: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# +|+13  9r|)3 4^) 9r3]u)|<3
# 1/1 [==============================] - 0s 10ms/step
# 4u+#0r  ]4^3 4u5+3^
# 2/2 [==============================] - 0s 4ms/step
# 905+|^6 )4+3  4u6u5+           3800k
# 1/1 [==============================] - 0s 10ms/step
# r313453 )4+3  ]u^3
# 1/1 [==============================] - 0s 8ms/step
#  145+ u9)4+3)  4u6u5+
# 1/1 [==============================] - 0s 10ms/step
# 14^6u463  3^61|5#
# 3/3 [==============================] - 0s 3ms/step
#     5+4r+ 0f +#|5 9r0]3<+ 6u+3^83r6 3800k 9r|)3 4^) 9r3]u)|<3
# 2/2 [==============================] - 0s 3ms/step
# 9r0)u<3) 8y 4^0^ym0u5 v01u^+33r5
# 1/1 [==============================] - 0s 9ms/step
# 9r|)3 4^) 9r3]u)|<3
# 1/1 [==============================] - 0s 9ms/step
# 8y ]4^3 4u5+3^
# 1/1 [==============================] - 0s 12ms/step
# <#49+3r
# 3/3 [==============================] - 0s 3ms/step
# |+ |5 4 +ru+# u^|v3r5411y 4<k^0w13)63)  +#4+ 4 5|^613 m4^ |^ 9055355|0^
# 2/2 [==============================] - 0s 4ms/step
# 0f 4 600) f0r+u^3  mu5+ 83 |^ w4^+ 0f 4 w|f3
# 3/3 [==============================] - 0s 3ms/step
# #0w3v3r 1|++13 k^0w^ +#3 f331|^65 0r v|3w5 0f 5u<# 4 m4^ m4y 83 0^ #|5
# 3/3 [==============================] - 0s 3ms/step
# f|r5+ 3^+3r|^6 4 ^3|6#80ur#00)  +#|5 +ru+# |5 50 w311 f|x3) |^ +#3 m|^)5
# 3/3 [==============================] - 0s 2ms/step
# 0f +#3 5urr0u^)|^6 f4m|1|35  +#4+ #3 |5 <0^5|)3r3) +#3 r|6#+fu1 9r093r+y
# 2/2 [==============================] - 0s 2ms/step
# 0f 50m3 0^3 0r 0+#3r 0f +#3|r )4u6#+3r5
# 3/3 [==============================] - 0s 2ms/step
#  my )34r mr  83^^3+   54|) #|5 14)y +0 #|m 0^3 )4y   #4v3 y0u #34r) +#4+
# 2/2 [==============================] - 0s 2ms/step
# ^3+#3rf|31) 94rk |5 13+ 4+ 145+
# 2/2 [==============================] - 0s 2ms/step
# mr  83^^3+ r391|3) +#4+ #3 #4) ^0+
# 3/3 [==============================] - 0s 3ms/step
#  8u+ |+ |5   r3+ur^3) 5#3   f0r mr5  10^6 #45 ]u5+ 833^ #3r3  4^) 5#3
# 1/1 [==============================] - 0s 11ms/step
# +01) m3 411 480u+ |+
# 1/1 [==============================] - 0s 9ms/step
# mr  83^^3+ m4)3 ^0 4^5w3r
# 3/3 [==============================] - 0s 2ms/step
#  )0 y0u ^0+ w4^+ +0 k^0w w#0 #45 +4k3^ |+   <r|3) #|5 w|f3 |m94+|3^+1y
# 2/2 [==============================] - 0s 2ms/step
#   y0u  w4^+ +0 +311 m3  4^) | #4v3 ^0 08]3<+|0^ +0 #34r|^6 |+
# 1/1 [==============================] - 0s 11ms/step
# +#|5 w45 |^v|+4+|0^ 3^0u6#
# 3/3 [==============================] - 0s 2ms/step
#  w#y  my )34r  y0u mu5+ k^0w  mr5  10^6 54y5 +#4+ ^3+#3rf|31) |5 +4k3^
# 3/3 [==============================] - 0s 2ms/step
# 8y 4 y0u^6 m4^ 0f 14r63 f0r+u^3 fr0m +#3 ^0r+# 0f 3^614^)  +#4+ #3 <4m3
# 3/3 [==============================] - 0s 2ms/step
# )0w^ 0^ m0^)4y |^ 4 <#4|53 4^) f0ur +0 533 +#3 914<3  4^) w45 50 mu<#
# 3/3 [==============================] - 0s 2ms/step
# )31|6#+3) w|+# |+  +#4+ #3 46r33) w|+# mr  m0rr|5 |mm3)|4+31y  +#4+ #3
# 3/3 [==============================] - 0s 2ms/step
# |5 +0 +4k3 9055355|0^ 83f0r3 m|<#431m45  4^) 50m3 0f #|5 53rv4^+5 4r3 +0
# 2/2 [==============================] - 0s 2ms/step
# 83 |^ +#3 #0u53 8y +#3 3^) 0f ^3x+ w33k
# 1/1 [==============================] - 0s 9ms/step
#  w#4+ |5 #|5 ^4m3
# 1/1 [==============================] - 0s 11ms/step
#  8|^613y
# 1/1 [==============================] - 0s 10ms/step
#  |5 #3 m4rr|3) 0r 5|^613
# 3/3 [==============================] - 0s 2ms/step
#  0#  5|^613  my )34r  +0 83 5ur3  4 5|^613 m4^ 0f 14r63 f0r+u^3  f0ur 0r
# 2/2 [==============================] - 0s 4ms/step
# f|v3 +#0u54^) 4 y34r  w#4+ 4 f|^3 +#|^6 f0r 0ur 6|r15
# 2/2 [==============================] - 0s 3ms/step
#  #0w 50  #0w <4^ |+ 4ff3<+ +#3m
# 3/3 [==============================] - 0s 1ms/step
#  my )34r mr  83^^3+   r391|3) #|5 w|f3   #0w <4^ y0u 83 50 +|r350m3  y0u
# 2/2 [==============================] - 0s 3ms/step
# mu5+ k^0w +#4+ | 4m +#|^k|^6 0f #|5 m4rry|^6 0^3 0f +#3m
# 2/2 [==============================] - 0s 2ms/step
#  |5 +#4+ #|5 )35|6^ |^ 53++1|^6 #3r3
# 3/3 [==============================] - 0s 2ms/step
#  )35|6^  ^0^53^53  #0w <4^ y0u +41k 50  8u+ |+ |5 v3ry 1|k31y +#4+ #3
# 3/3 [==============================] - 0s 2ms/step
#  m4y  f411 |^ 10v3 w|+# 0^3 0f +#3m  4^) +#3r3f0r3 y0u mu5+ v|5|+ #|m 45
# 1/1 [==============================] - 0s 11ms/step
# 500^ 45 #3 <0m35
# 3/3 [==============================] - 0s 2ms/step
#  | 533 ^0 0<<45|0^ f0r +#4+  y0u 4^) +#3 6|r15 m4y 60  0r y0u m4y 53^)
# 3/3 [==============================] - 0s 2ms/step
# +#3m 8y +#3m531v35  w#|<# 93r#495 w|11 83 5+|11 83++3r  f0r 45 y0u 4r3
# 3/3 [==============================] - 0s 3ms/step
# 45 #4^)50m3 45 4^y 0f +#3m  mr  8|^613y m4y 1|k3 y0u +#3 835+ 0f +#3
# 1/1 [==============================] - 0s 9ms/step
# 94r+y
# 3/3 [==============================] - 0s 2ms/step
#  my )34r  y0u f14++3r m3  | <3r+4|^1y  #4v3  #4) my 5#4r3 0f 834u+y  8u+
# 3/3 [==============================] - 0s 2ms/step
# | )0 ^0+ 9r3+3^) +0 83 4^y+#|^6 3x+r40r)|^4ry ^0w  w#3^ 4 w0m4^ #45 f|v3
# 3/3 [==============================] - 0s 2ms/step
# 6r0w^ u9 )4u6#+3r5  5#3 0u6#+ +0 6|v3 0v3r +#|^k|^6 0f #3r 0w^ 834u+y
# 2/2 [==============================] - 0s 2ms/step
#  |^ 5u<# <4535  4 w0m4^ #45 ^0+ 0f+3^ mu<# 834u+y +0 +#|^k 0f
# 3/3 [==============================] - 0s 2ms/step
#  8u+  my )34r  y0u mu5+ |^)33) 60 4^) 533 mr  8|^613y w#3^ #3 <0m35 |^+0
# 1/1 [==============================] - 0s 10ms/step
# +#3 ^3|6#80ur#00)
# 2/2 [==============================] - 0s 2ms/step
#  |+ |5 m0r3 +#4^ | 3^6463 f0r  | 455ur3 y0u
# 3/3 [==============================] - 0s 2ms/step
#  8u+ <0^5|)3r y0ur )4u6#+3r5  0^1y +#|^k w#4+ 4^ 35+481|5#m3^+ |+ w0u1)
# 3/3 [==============================] - 0s 3ms/step
# 83 f0r 0^3 0f +#3m  5|r w|11|4m 4^) 14)y 1u<45 4r3 )3+3rm|^3) +0
# 3/3 [==============================] - 0s 3ms/step
# 60  m3r31y 0^ +#4+ 4<<0u^+  f0r |^ 63^3r41  y0u k^0w  +#3y v|5|+ ^0
# 3/3 [==============================] - 0s 2ms/step
# ^3w<0m3r5  |^)33) y0u mu5+ 60  f0r |+ w|11 83 |m9055|813 f0r  u5  +0
# 1/1 [==============================] - 0s 11ms/step
# v|5|+ #|m |f y0u )0 ^0+
# 3/3 [==============================] - 0s 2ms/step
#  y0u 4r3 0v3r 5<ru9u10u5  5ur31y  | )4r3 54y mr  8|^613y w|11 83 v3ry
# 3/3 [==============================] - 0s 3ms/step
# 614) +0 533 y0u  4^) | w|11 53^) 4 f3w 1|^35 8y y0u +0 455ur3 #|m 0f my
# 3/3 [==============================] - 0s 2ms/step
# #34r+y <0^53^+ +0 #|5 m4rry|^6 w#|<#3v3r #3 <#00535 0f +#3 6|r15  +#0u6#
# 2/2 [==============================] - 0s 4ms/step
# | mu5+ +#r0w |^ 4 600) w0r) f0r my 1|++13 1|77y
# 3/3 [==============================] - 0s 2ms/step
#  | )35|r3 y0u w|11 )0 ^0 5u<# +#|^6  1|77y |5 ^0+ 4 8|+ 83++3r +#4^ +#3
# 3/3 [==============================] - 0s 3ms/step
# 0+#3r5  4^) | 4m 5ur3 5#3 |5 ^0+ #41f 50 #4^)50m3 45 ]4^3  ^0r #41f 50
# 3/3 [==============================] - 0s 3ms/step
# 600) #um0ur3) 45 1y)|4  8u+ y0u 4r3 41w4y5 6|v|^6  #3r  +#3 9r3f3r3^<3
# 3/3 [==============================] - 0s 2ms/step
#  +#3y #4v3 ^0^3 0f +#3m mu<# +0 r3<0mm3^) +#3m   r391|3) #3   +#3y 4r3
# 3/3 [==============================] - 0s 2ms/step
# 411 5|11y 4^) |6^0r4^+ 1|k3 0+#3r 6|r15  8u+ 1|77y #45 50m3+#|^6 m0r3 0f
# 1/1 [==============================] - 0s 11ms/step
# &u|<k^355 +#4^ #3r 5|5+3r5
# 3/3 [==============================] - 0s 3ms/step
#  mr  83^^3+  #0w  <4^  y0u 48u53 y0ur 0w^ <#|1)r3^ |^ 5u<# 4 w4y  y0u
# 3/3 [==============================] - 0s 2ms/step
# +4k3 )31|6#+ |^ v3x|^6 m3  y0u #4v3 ^0 <0m9455|0^ f0r my 900r ^3rv35
# 3/3 [==============================] - 0s 2ms/step
#  y0u m|5+4k3 m3  my )34r  | #4v3 4 #|6# r3593<+ f0r y0ur ^3rv35  +#3y
# 3/3 [==============================] - 0s 2ms/step
# 4r3 my 01) fr|3^)5  | #4v3 #34r) y0u m3^+|0^ +#3m w|+# <0^5|)3r4+|0^
# 2/2 [==============================] - 0s 4ms/step
# +#353 145+ +w3^+y y34r5 4+ 1345+
# 2/2 [==============================] - 0s 2ms/step
#  4#  y0u )0 ^0+ k^0w w#4+ | 5uff3r
# 3/3 [==============================] - 0s 2ms/step
#  8u+ | #093 y0u w|11 63+ 0v3r |+  4^) 1|v3 +0 533 m4^y y0u^6 m3^ 0f f0ur
# 2/2 [==============================] - 0s 5ms/step
# +#0u54^) 4 y34r <0m3 |^+0 +#3 ^3|6#80ur#00)
# 3/3 [==============================] - 0s 2ms/step
#  |+ w|11 83 ^0 u53 +0 u5  |f +w3^+y 5u<# 5#0u1) <0m3  5|^<3 y0u w|11 ^0+
# 1/1 [==============================] - 0s 11ms/step
# v|5|+ +#3m
# 3/3 [==============================] - 0s 2ms/step
#  )393^) u90^ |+  my )34r  +#4+ w#3^ +#3r3 4r3 +w3^+y  | w|11 v|5|+ +#3m
# 1/1 [==============================] - 0s 9ms/step
# 411
# 3/3 [==============================] - 0s 3ms/step
# mr  83^^3+ w45 50 0)) 4 m|x+ur3 0f &u|<k 94r+5  54r<45+|< #um0ur
# 3/3 [==============================] - 0s 2ms/step
# r353rv3  4^) <49r|<3  +#4+ +#3 3x93r|3^<3 0f +#r33 4^) +w3^+y y34r5 #4)
# 3/3 [==============================] - 0s 2ms/step
# 833^ |^5uff|<|3^+ +0 m4k3 #|5 w|f3 u^)3r5+4^) #|5 <#4r4<+3r   #3r  m|^)
# 3/3 [==============================] - 0s 2ms/step
# w45 1355 )|ff|<u1+ +0 )3v3109  5#3 w45 4 w0m4^ 0f m34^ u^)3r5+4^)|^6
# 3/3 [==============================] - 0s 3ms/step
# 1|++13 |^f0rm4+|0^  4^) u^<3r+4|^ +3m93r  w#3^ 5#3 w45 )|5<0^+3^+3)
# 3/3 [==============================] - 0s 2ms/step
# 5#3 f4^<|3) #3r531f ^3rv0u5  +#3 8u5|^355 0f #3r 1|f3 w45 +0 63+ #3r
# 2/2 [==============================] - 0s 4ms/step
# )4u6#+3r5 m4rr|3)  |+5 5014<3 w45 v|5|+|^6 4^) ^3w5
# 1/1 [==============================] - 0s 11ms/step
# <#49+3r
# 3/3 [==============================] - 0s 2ms/step
# mr  83^^3+ w45 4m0^6 +#3 34r1|35+ 0f +#053 w#0 w4|+3) 0^ mr  8|^613y  #3
# 3/3 [==============================] - 0s 2ms/step
# #4) 41w4y5 |^+3^)3) +0 v|5|+ #|m  +#0u6# +0 +#3 145+ 41w4y5 455ur|^6
# 3/3 [==============================] - 0s 2ms/step
# #|5 w|f3 +#4+ #3 5#0u1) ^0+ 60  4^) +|11 +#3 3v3^|^6 4f+3r +#3 v|5|+ w45
# 3/3 [==============================] - 0s 2ms/step
# 94|) 5#3 #4) ^0 k^0w13)63 0f |+  |+ w45 +#3^ )|5<1053) |^ +#3 f0110w|^6
# 3/3 [==============================] - 0s 2ms/step
# m4^^3r  0853rv|^6 #|5 53<0^) )4u6#+3r 3m910y3) |^ +r|mm|^6 4 #4+  #3
# 1/1 [==============================] - 0s 9ms/step
# 5u))3^1y 4))r3553) #3r w|+#
# 2/2 [==============================] - 0s 2ms/step
#  | #093 mr  8|^613y w|11 1|k3 |+  1|77y
# 3/3 [==============================] - 0s 2ms/step
#  w3 4r3 ^0+ |^ 4 w4y +0 k^0w  w#4+  mr  8|^613y 1|k35   54|) #3r m0+#3r
# 2/2 [==============================] - 0s 2ms/step
# r353^+fu11y   5|^<3 w3 4r3 ^0+ +0 v|5|+
# 3/3 [==============================] - 0s 2ms/step
#  8u+ y0u f0r63+  m4mm4   54|) 31|7483+#   +#4+ w3 5#411 m33+ #|m 4+ +#3
# 2/2 [==============================] - 0s 4ms/step
# 4553m81|35  4^) +#4+ mr5  10^6 9r0m|53) +0 |^+r0)u<3 #|m
# 3/3 [==============================] - 0s 2ms/step
#  | )0 ^0+ 831|3v3 mr5  10^6 w|11 )0 4^y 5u<# +#|^6  5#3 #45 +w0 ^|3<35
# 3/3 [==============================] - 0s 2ms/step
# 0f #3r 0w^  5#3 |5 4 531f|5#  #y90<r|+|<41 w0m4^  4^) | #4v3 ^0 09|^|0^
# 1/1 [==============================] - 0s 8ms/step
# 0f #3r
# 3/3 [==============================] - 0s 2ms/step
#  ^0 m0r3 #4v3 |   54|) mr  83^^3+   4^) | 4m 614) +0 f|^) +#4+ y0u )0
# 1/1 [==============================] - 0s 8ms/step
# ^0+ )393^) 0^ #3r 53rv|^6 y0u
# 3/3 [==============================] - 0s 2ms/step
# mr5  83^^3+ )3|6^3) ^0+ +0 m4k3 4^y r391y  8u+  u^4813 +0 <0^+4|^
# 2/2 [==============================] - 0s 2ms/step
# #3r531f  8364^ 5<01)|^6 0^3 0f #3r )4u6#+3r5
# 3/3 [==============================] - 0s 3ms/step
#  )0^ + k339 <0u6#|^6 50  k|++y  f0r #34v3^ 5 54k3  #4v3 4 1|++13
# 2/2 [==============================] - 0s 4ms/step
# <0m9455|0^ 0^ my ^3rv35  y0u +34r +#3m +0 9|3<35
# 3/3 [==============================] - 0s 2ms/step
#  k|++y #45 ^0 )|5<r3+|0^ |^ #3r <0u6#5   54|) #3r f4+#3r   5#3 +|m35
# 1/1 [==============================] - 0s 11ms/step
# +#3m |11
# 3/3 [==============================] - 0s 2ms/step
#  | )0 ^0+ <0u6# f0r my 0w^ 4mu53m3^+   r391|3) k|++y fr3+fu11y   w#3^ |5
# 1/1 [==============================] - 0s 11ms/step
# y0ur ^3x+ 8411 +0 83  1|77y
# 1/1 [==============================] - 0s 11ms/step
#  +0 m0rr0w f0r+^|6#+
# 3/3 [==============================] - 0s 2ms/step
#  4y3  50 |+ |5   <r|3) #3r m0+#3r   4^) mr5  10^6 )035 ^0+ <0m3 84<k
# 3/3 [==============================] - 0s 3ms/step
# +|11 +#3 )4y 83f0r3  50 |+ w|11 83 |m9055|813 f0r #3r +0 |^+r0)u<3 #|m
# 2/2 [==============================] - 0s 5ms/step
# f0r 5#3 w|11 ^0+ k^0w #|m #3r531f
# 3/3 [==============================] - 0s 3ms/step
#  +#3^  my )34r  y0u m4y #4v3 +#3 4)v4^+463 0f y0ur fr|3^)  4^) |^+r0)u<3
# 1/1 [==============================] - 0s 9ms/step
# mr  8|^613y +0  #3r
# 3/3 [==============================] - 0s 3ms/step
#  |m9055|813  mr  83^^3+  |m9055|813  w#3^ | 4m ^0+ 4<&u4|^+3) w|+# #|m
# 2/2 [==============================] - 0s 2ms/step
# my531f  #0w <4^ y0u 83 50 +345|^6
# 3/3 [==============================] - 0s 2ms/step
#  | #0^0ur y0ur <|r<um593<+|0^  4 f0r+^|6#+ 5 4<&u4|^+4^<3 |5 <3r+4|^1y
# 3/3 [==============================] - 0s 2ms/step
# v3ry 1|++13  0^3 <4^^0+ k^0w w#4+ 4 m4^ r3411y |5 8y +#3 3^) 0f 4
# 3/3 [==============================] - 0s 2ms/step
# f0r+^|6#+  8u+ |f  w3  )0 ^0+ v3^+ur3 50m380)y 3153 w|11  4^) 4f+3r 411
# 3/3 [==============================] - 0s 2ms/step
# mr5  10^6 4^) #3r )4u6#+3r5 mu5+ 5+4^) +#3|r <#4^<3  4^)  +#3r3f0r3  45
# 3/3 [==============================] - 0s 2ms/step
# 5#3 w|11 +#|^k |+ 4^ 4<+ 0f k|^)^355  |f y0u )3<1|^3 +#3 0ff|<3  | w|11
# 1/1 [==============================] - 0s 11ms/step
# +4k3 |+ 0^ my531f
# 3/3 [==============================] - 0s 2ms/step
# +#3 6|r15 5+4r3) 4+ +#3|r f4+#3r  mr5  83^^3+ 54|) 0^1y   ^0^53^53
# 1/1 [==============================] - 0s 9ms/step
# ^0^53^53
# 3/3 [==============================] - 0s 3ms/step
#  w#4+ <4^ 83 +#3 m34^|^6 0f +#4+ 3m9#4+|< 3x<14m4+|0^   <r|3) #3   )0
# 3/3 [==============================] - 0s 2ms/step
# y0u <0^5|)3r +#3 f0rm5 0f |^+r0)u<+|0^  4^) +#3 5+r355 +#4+ |5 14|) 0^
# 3/3 [==============================] - 0s 2ms/step
# +#3m  45 ^0^53^53  | <4^^0+ &u|+3 46r33 w|+# y0u  +#3r3   w#4+ 54y y0u
# 3/3 [==============================] - 0s 2ms/step
# m4ry  f0r y0u 4r3 4 y0u^6 14)y 0f )339 r3f13<+|0^  | k^0w  4^) r34)
# 1/1 [==============================] - 0s 8ms/step
# 6r34+ 800k5 4^) m4k3 3x+r4<+5
# 2/2 [==============================] - 0s 4ms/step
# m4ry w|5#3) +0 54y 50m3+#|^6 53^5|813  8u+ k^3w ^0+ #0w
# 3/3 [==============================] - 0s 2ms/step
#  w#|13 m4ry |5 4)]u5+|^6 #3r |)345   #3 <0^+|^u3)   13+ u5 r3+ur^ +0 mr
# 1/1 [==============================] - 0s 9ms/step
# 8|^613y
# 2/2 [==============================] - 0s 4ms/step
#  | 4m 5|<k 0f mr  8|^613y   <r|3) #|5 w|f3
# 3/3 [==============================] - 0s 2ms/step
#  | 4m 50rry +0 #34r  +#4+   8u+ w#y )|) ^0+ y0u +311 m3 +#4+ 83f0r3  |f
# 3/3 [==============================] - 0s 3ms/step
# | #4) k^0w^ 45 mu<# +#|5 m0r^|^6 | <3r+4|^1y w0u1) ^0+ #4v3 <4113)
# 3/3 [==============================] - 0s 2ms/step
# 0^ #|m  |+ |5 v3ry u^1u<ky  8u+ 45 | #4v3 4<+u411y 94|) +#3 v|5|+  w3
# 2/2 [==============================] - 0s 4ms/step
# <4^^0+ 35<493 +#3 4<&u4|^+4^<3 ^0w
# 3/3 [==============================] - 0s 2ms/step
# +#3 45+0^|5#m3^+ 0f +#3 14)|35 w45 ]u5+ w#4+ #3 w|5#3)  +#4+ 0f mr5
# 3/3 [==============================] - 0s 2ms/step
# 83^^3+ 93r#495 5ur9455|^6 +#3 r35+  +#0u6#  w#3^ +#3 f|r5+ +umu1+ 0f ]0y
# 3/3 [==============================] - 0s 2ms/step
# w45 0v3r  5#3 8364^ +0 )3<14r3 +#4+ |+ w45 w#4+ 5#3 #4) 3x93<+3) 411 +#3
# 1/1 [==============================] - 0s 8ms/step
# w#|13
# 3/3 [==============================] - 0s 3ms/step
#  #0w 600) |+ w45 |^ y0u  my )34r mr  83^^3+  8u+ | k^3w | 5#0u1)
# 3/3 [==============================] - 0s 3ms/step
# 93r5u4)3 y0u 4+ 145+  | w45 5ur3 y0u 10v3) y0ur 6|r15 +00 w311 +0
# 3/3 [==============================] - 0s 2ms/step
# ^3613<+ 5u<# 4^ 4<&u4|^+4^<3  w311  #0w 913453) | 4m  4^) |+ |5 5u<# 4
# 3/3 [==============================] - 0s 2ms/step
# 600) ]0k3  +00  +#4+ y0u 5#0u1) #4v3 60^3 +#|5 m0r^|^6 4^) ^3v3r 54|) 4
# 1/1 [==============================] - 0s 8ms/step
# w0r) 480u+ |+ +|11 ^0w
# 3/3 [==============================] - 0s 2ms/step
#  ^0w  k|++y  y0u m4y <0u6# 45 mu<# 45 y0u <#0053   54|) mr  83^^3+  4^)
# 3/3 [==============================] - 0s 2ms/step
# 45 #3 590k3  #3 13f+ +#3 r00m  f4+|6u3) w|+# +#3 r49+ur35 0f #|5 w|f3
# 3/3 [==============================] - 0s 2ms/step
#  w#4+ 4^ 3x<3113^+ f4+#3r y0u #4v3  6|r15   54|) 5#3  w#3^ +#3 )00r w45
# 3/3 [==============================] - 0s 2ms/step
# 5#u+   | )0 ^0+ k^0w #0w y0u w|11 3v3r m4k3 #|m 4m3^)5 f0r #|5 k|^)^355
# 3/3 [==============================] - 0s 2ms/step
# 0r m3  3|+#3r  f0r +#4+ m4++3r  4+ 0ur +|m3 0f 1|f3 |+ |5 ^0+ 50
# 3/3 [==============================] - 0s 2ms/step
# 913454^+  | <4^ +311 y0u  +0 83 m4k|^6 ^3w 4<&u4|^+4^<35 3v3ry )4y  8u+
# 3/3 [==============================] - 0s 2ms/step
# f0r y0ur 54k35  w3 w0u1) )0 4^y+#|^6  1y)|4  my 10v3  +#0u6# y0u  4r3
# 3/3 [==============================] - 0s 2ms/step
# +#3 y0u^635+  | )4r3 54y mr  8|^613y w|11 )4^<3 w|+# y0u 4+ +#3 ^3x+
# 1/1 [==============================] - 0s 8ms/step
# 8411
# 3/3 [==============================] - 0s 3ms/step
#  0#   54|) 1y)|4 5+0u+1y   | 4m ^0+ 4fr4|)  f0r +#0u6# |  4m  +#3
# 1/1 [==============================] - 0s 11ms/step
# y0u^635+  | m +#3 +41135+
# 3/3 [==============================] - 0s 2ms/step
# +#3 r35+ 0f +#3 3v3^|^6 w45 593^+ |^ <0^]3<+ur|^6 #0w 500^ #3 w0u1)
# 3/3 [==============================] - 0s 2ms/step
# r3+ur^ mr  83^^3+ 5 v|5|+  4^) )3+3rm|^|^6 w#3^ +#3y 5#0u1) 45k #|m +0
# 1/1 [==============================] - 0s 9ms/step
# )|^^3r
# 1/1 [==============================] - 0s 10ms/step
# <#49+3r
# 3/3 [==============================] - 0s 2ms/step
# ^0+ 411 +#4+ mr5  83^^3+  #0w3v3r  w|+# +#3 455|5+4^<3 0f #3r f|v3
# 3/3 [==============================] - 0s 2ms/step
# )4u6#+3r5  <0u1) 45k 0^ +#3 5u8]3<+  w45 5uff|<|3^+ +0 )r4w fr0m #3r
# 3/3 [==============================] - 0s 2ms/step
# #u584^) 4^y 54+|5f4<+0ry )35<r|9+|0^ 0f mr  8|^613y  +#3y 4++4<k3) #|m
# 3/3 [==============================] - 0s 2ms/step
# |^ v4r|0u5 w4y5  w|+# 84r3f4<3) &u35+|0^5  |^63^|0u5 5u9905|+|0^5  4^)
# 3/3 [==============================] - 0s 2ms/step
# )|5+4^+ 5urm|535  8u+ #3 31u)3) +#3 5k|11 0f +#3m 411  4^) +#3y w3r3 4+
# 3/3 [==============================] - 0s 2ms/step
# 145+ 081|63) +0 4<<39+ +#3 53<0^) #4^) |^+311|63^<3 0f +#3|r ^3|6#80ur
# 3/3 [==============================] - 0s 2ms/step
# 14)y 1u<45  #3r r390r+ w45 #|6#1y f4v0ur4813  5|r w|11|4m #4) 833^
# 3/3 [==============================] - 0s 2ms/step
# )31|6#+3) w|+# #|m  #3 w45 &u|+3 y0u^6  w0^)3rfu11y #4^)50m3  3x+r3m31y
# 3/3 [==============================] - 0s 2ms/step
# 46r334813  4^)  +0 <r0w^ +#3 w#013  #3 m34^+ +0 83 4+ +#3 ^3x+ 4553m81y
# 3/3 [==============================] - 0s 2ms/step
# w|+# 4 14r63 94r+y  ^0+#|^6 <0u1) 83 m0r3 )31|6#+fu1  +0 83 f0^) 0f
# 3/3 [==============================] - 0s 2ms/step
# )4^<|^6 w45 4 <3r+4|^ 5+39 +0w4r)5 f411|^6 |^ 10v3  4^) v3ry 1|v31y
# 2/2 [==============================] - 0s 5ms/step
# #0935 0f mr  8|^613y 5 #34r+ w3r3 3^+3r+4|^3)
# 3/3 [==============================] - 0s 2ms/step
#  |f | <4^ 8u+ 533 0^3 0f my )4u6#+3r5 #499|1y 53++13) 4+ ^3+#3rf|31)
# 3/3 [==============================] - 0s 2ms/step
# 54|) mr5  83^^3+ +0 #3r #u584^)   4^) 411 +#3 0+#3r5 3&u411y w311
# 2/2 [==============================] - 0s 3ms/step
# m4rr|3)  | 5#411 #4v3 ^0+#|^6 +0 w|5# f0r
# 3/3 [==============================] - 0s 2ms/step
# |^ 4 f3w )4y5 mr  8|^613y r3+ur^3) mr  83^^3+ 5 v|5|+  4^) 54+ 480u+
# 3/3 [==============================] - 0s 2ms/step
# +3^ m|^u+35 w|+# #|m |^ #|5 1|8r4ry  #3 #4) 3^+3r+4|^3) #0935 0f 83|^6
# 2/2 [==============================] - 0s 2ms/step
# 4)m|++3) +0 4 5|6#+ 0f +#3 y0u^6 14)|35  0f w#053 834u+y #3 #4)
# 3/3 [==============================] - 0s 2ms/step
# #34r) mu<#  8u+ #3 54w 0^1y +#3 f4+#3r  +#3 14)|35 w3r3 50m3w#4+ m0r3
# 3/3 [==============================] - 0s 2ms/step
# f0r+u^4+3  f0r +#3y #4) +#3 4)v4^+463 0f 45<3r+4|^|^6 fr0m 4^ u993r
# 2/2 [==============================] - 0s 2ms/step
# w|^)0w +#4+ #3 w0r3 4 81u3 <04+  4^) r0)3 4 814<k #0r53
# 3/3 [==============================] - 0s 2ms/step
# 4^ |^v|+4+|0^ +0 )|^^3r w45 500^ 4f+3rw4r)5 )|594+<#3)  4^) 41r34)y
# 3/3 [==============================] - 0s 2ms/step
# #4) mr5  83^^3+ 914^^3) +#3 <0ur535 +#4+ w3r3 +0 )0 <r3)|+ +0 #3r
# 3/3 [==============================] - 0s 3ms/step
# #0u53k339|^6  w#3^ 4^ 4^5w3r 4rr|v3) w#|<# )3f3rr3) |+ 411  mr  8|^613y
# 3/3 [==============================] - 0s 2ms/step
# w45 081|63) +0 83 |^ +0w^ +#3 f0110w|^6 )4y  4^)  <0^53&u3^+1y  u^4813
# 3/3 [==============================] - 0s 2ms/step
# +0 4<<39+ +#3 #0^0ur 0f +#3|r |^v|+4+|0^  3+<  mr5  83^^3+ w45 &u|+3
# 3/3 [==============================] - 0s 2ms/step
# )|5<0^<3r+3)  5#3 <0u1) ^0+ |m46|^3 w#4+ 8u5|^355 #3 <0u1) #4v3 |^ +0w^
# 3/3 [==============================] - 0s 2ms/step
# 50 500^ 4f+3r #|5 4rr|v41 |^ #3r+f0r)5#|r3  4^) 5#3 8364^ +0 f34r +#4+
# 3/3 [==============================] - 0s 2ms/step
# #3 m|6#+ 83 41w4y5 f1y|^6 480u+ fr0m 0^3 914<3 +0 4^0+#3r  4^) ^3v3r
# 3/3 [==============================] - 0s 2ms/step
# 53++13) 4+ ^3+#3rf|31) 45 #3 0u6#+ +0 83  14)y 1u<45 &u|3+3) #3r f34r5
# 3/3 [==============================] - 0s 2ms/step
# 4 1|++13 8y 5+4r+|^6 +#3 |)34 0f #|5 83|^6 60^3 +0 10^)0^ 0^1y +0 63+
# 3/3 [==============================] - 0s 2ms/step
# 4 14r63 94r+y f0r +#3 8411  4^) 4 r390r+ 500^ f0110w3) +#4+ mr  8|^613y
# 3/3 [==============================] - 0s 2ms/step
# w45 +0 8r|^6 +w31v3 14)|35 4^) 53v3^ 63^+13m3^ w|+# #|m +0 +#3 4553m81y
# 3/3 [==============================] - 0s 2ms/step
# +#3 6|r15 6r|3v3) 0v3r 5u<# 4 ^um83r 0f 14)|35  8u+ w3r3 <0mf0r+3) +#3
# 3/3 [==============================] - 0s 2ms/step
# )4y 83f0r3 +#3 8411 8y #34r|^6  +#4+ |^5+34) 0f +w31v3 #3 8r0u6#+ 0^1y
# 3/3 [==============================] - 0s 5ms/step
# 5|x w|+# #|m fr0m 10^)0^  #|5 f|v3 5|5+3r5 4^) 4 <0u5|^  4^) w#3^
# 2/2 [==============================] - 0s 4ms/step
# +#3 94r+y 3^+3r3) +#3 4553m81y r00m |+ <0^5|5+3) 0f 0^1y f|v3
# 3/3 [==============================] - 0s 3ms/step
# 41+063+#3r  mr  8|^613y  #|5 +w0 5|5+3r5  +#3 #u584^) 0f +#3 31)35+  4^)
# 1/1 [==============================] - 0s 10ms/step
# 4^0+#3r y0u^6 m4^
# 3/3 [==============================] - 0s 2ms/step
# mr  8|^613y w45 600) 100k|^6 4^) 63^+13m4^1|k3  #3 #4) 4 913454^+
# 3/3 [==============================] - 0s 2ms/step
# <0u^+3^4^<3  4^) 345y  u^4ff3<+3) m4^^3r5  #|5 5|5+3r5 w3r3 f|^3 w0m3^
# 3/3 [==============================] - 0s 3ms/step
# w|+# 4^ 4|r 0f )3<|)3) f45#|0^  #|5 8r0+#3r |^ 14w  mr  #ur5+  m3r31y
# 3/3 [==============================] - 0s 3ms/step
# 100k3) +#3 63^+13m4^  8u+ #|5 fr|3^) mr  )4r<y 500^ )r3w +#3 4++3^+|0^
# 3/3 [==============================] - 0s 2ms/step
# 0f +#3 r00m 8y #|5 f|^3  +411 93r50^  #4^)50m3 f34+ur35  ^0813 m|3^  4^)
# 2/2 [==============================] - 0s 3ms/step
# +#3 r390r+ w#|<# w45 |^ 63^3r41 <|r<u14+|0^ w|+#|^ f|v3 m|^u+35
# 3/3 [==============================] - 0s 2ms/step
# 4f+3r #|5 3^+r4^<3  0f #|5 #4v|^6 +3^ +#0u54^) 4 y34r  +#3 63^+13m3^
# 3/3 [==============================] - 0s 3ms/step
# 9r0^0u^<3) #|m +0 83 4 f|^3 f|6ur3 0f 4 m4^  +#3 14)|35 )3<14r3) #3
# 3/3 [==============================] - 0s 2ms/step
# w45 mu<# #4^)50m3r +#4^ mr  8|^613y  4^) #3 w45 100k3) 4+ w|+# 6r34+
# 3/3 [==============================] - 0s 2ms/step
# 4)m|r4+|0^ f0r 480u+ #41f +#3 3v3^|^6  +|11 #|5 m4^^3r5 64v3 4 )|56u5+
# 3/3 [==============================] - 0s 2ms/step
# w#|<# +ur^3) +#3 +|)3 0f #|5 909u14r|+y  f0r #3 w45 )|5<0v3r3) +0 83
# 3/3 [==============================] - 0s 2ms/step
# 9r0u)  +0 83 480v3 #|5 <0m94^y  4^) 480v3 83|^6 913453)  4^) ^0+ 411
# 3/3 [==============================] - 0s 3ms/step
# #|5 14r63 35+4+3 |^ )3r8y5#|r3 <0u1) +#3^ 54v3 #|m fr0m #4v|^6 4 m05+
# 3/3 [==============================] - 0s 2ms/step
# f0r8|))|^6  )|546r334813 <0u^+3^4^<3  4^) 83|^6 u^w0r+#y +0 83 <0m94r3)
# 1/1 [==============================] - 0s 11ms/step
# w|+# #|5 fr|3^)
# 3/3 [==============================] - 0s 2ms/step
# mr  8|^613y #4) 500^ m4)3 #|m531f 4<&u4|^+3) w|+# 411 +#3 9r|^<|941
# 3/3 [==============================] - 0s 2ms/step
# 930913 |^ +#3 r00m  #3 w45 1|v31y 4^) u^r353rv3)  )4^<3) 3v3ry )4^<3
# 2/2 [==============================] - 0s 2ms/step
# w45 4^6ry +#4+ +#3 8411 <1053) 50 34r1y  4^) +41k3) 0f 6|v|^6
# 3/3 [==============================] - 0s 2ms/step
# 0^3 #|m531f 4+ ^3+#3rf|31)  5u<# 4m|4813 &u41|+|35 mu5+ 5934k f0r
# 3/3 [==============================] - 0s 2ms/step
# +#3m531v35  w#4+ 4 <0^+r45+ 83+w33^ #|m 4^) #|5 fr|3^)  mr  )4r<y )4^<3)
# 3/3 [==============================] - 0s 2ms/step
# 0^1y 0^<3 w|+# mr5  #ur5+ 4^) 0^<3 w|+# m|55 8|^613y  )3<1|^3) 83|^6
# 3/3 [==============================] - 0s 4ms/step
# |^+r0)u<3) +0 4^y 0+#3r 14)y  4^) 593^+ +#3 r35+ 0f +#3 3v3^|^6 |^
# 3/3 [==============================] - 0s 2ms/step
# w41k|^6 480u+ +#3 r00m  5934k|^6 0<<45|0^411y +0 0^3 0f #|5 0w^ 94r+y
# 3/3 [==============================] - 0s 2ms/step
# #|5 <#4r4<+3r w45 )3<|)3)  #3 w45 +#3 9r0u)35+  m05+ )|546r334813 m4^
# 3/3 [==============================] - 0s 2ms/step
# |^ +#3 w0r1)  4^) 3v3ry80)y #093) +#4+ #3 w0u1) ^3v3r <0m3 +#3r3 464|^
# 3/3 [==============================] - 0s 2ms/step
# 4m0^65+ +#3 m05+ v|013^+ 464|^5+ #|m w45 mr5  83^^3+  w#053 )|51|k3 0f
# 3/3 [==============================] - 0s 2ms/step
# #|5 63^3r41 83#4v|0ur w45 5#4r93^3) |^+0 94r+|<u14r r353^+m3^+ 8y #|5
# 2/2 [==============================] - 0s 2ms/step
# #4v|^6 51|6#+3) 0^3 0f #3r )4u6#+3r5
# 3/3 [==============================] - 0s 2ms/step
# 31|7483+# 83^^3+ #4) 833^ 081|63)  8y +#3 5<4r<|+y 0f 63^+13m3^  +0 5|+
# 3/3 [==============================] - 0s 2ms/step
# )0w^ f0r +w0 )4^<35  4^) )ur|^6 94r+ 0f +#4+ +|m3  mr  )4r<y #4) 833^
# 3/3 [==============================] - 0s 2ms/step
# 5+4^)|^6 ^34r 3^0u6# f0r #3r +0 #34r 4 <0^v3r54+|0^ 83+w33^ #|m 4^) mr
# 3/3 [==============================] - 0s 2ms/step
# 8|^613y  w#0 <4m3 fr0m +#3 )4^<3 f0r 4 f3w m|^u+35  +0 9r355 #|5 fr|3^)
# 1/1 [==============================] - 0s 11ms/step
# +0 ]0|^ |+
# 3/3 [==============================] - 0s 2ms/step
#  <0m3  )4r<y   54|) #3   | mu5+ #4v3 y0u )4^<3  | #4+3 +0 533 y0u
# 3/3 [==============================] - 0s 2ms/step
# 5+4^)|^6 480u+ 8y y0ur531f |^ +#|5 5+u9|) m4^^3r  y0u #4) mu<# 83++3r
# 1/1 [==============================] - 0s 9ms/step
# )4^<3
# 2/2 [==============================] - 0s 3ms/step
#  | <3r+4|^1y 5#411 ^0+  y0u k^0w #0w | )3+35+ |+  u^1355 | 4m
# 3/3 [==============================] - 0s 3ms/step
# 94r+|<u14r1y 4<&u4|^+3) w|+# my 94r+^3r  4+ 5u<# 4^ 4553m81y 45 +#|5
# 3/3 [==============================] - 0s 2ms/step
# |+ w0u1) 83 |^5u990r+4813  y0ur 5|5+3r5 4r3 3^6463)  4^) +#3r3 |5 ^0+
# 3/3 [==============================] - 0s 2ms/step
# 4^0+#3r w0m4^ |^ +#3 r00m w#0m |+ w0u1) ^0+ 83 4 9u^|5#m3^+ +0 m3 +0
# 1/1 [==============================] - 0s 12ms/step
# 5+4^) u9 w|+#
# 3/3 [==============================] - 0s 2ms/step
#  | w0u1) ^0+ 83 50 f45+|)|0u5 45 y0u 4r3   <r|3) mr  8|^613y   f0r 4
# 3/3 [==============================] - 0s 2ms/step
# k|^6)0m  u90^ my #0^0ur  | ^3v3r m3+ w|+# 50 m4^y 913454^+ 6|r15 |^
# 3/3 [==============================] - 0s 2ms/step
# my 1|f3 45 | #4v3 +#|5 3v3^|^6  4^) +#3r3 4r3 53v3r41 0f +#3m y0u 533
# 1/1 [==============================] - 0s 11ms/step
# u^<0mm0^1y 9r3++y
# 3/3 [==============================] - 0s 2ms/step
#   y0u  4r3 )4^<|^6 w|+# +#3 0^1y #4^)50m3 6|r1 |^ +#3 r00m   54|) mr
# 2/2 [==============================] - 0s 4ms/step
# )4r<y  100k|^6 4+ +#3 31)35+ m|55 83^^3+
# 3/3 [==============================] - 0s 2ms/step
#  0#  5#3 |5 +#3 m05+ 834u+|fu1 <r34+ur3 | 3v3r 83#31)  8u+ +#3r3 |5 0^3
# 3/3 [==============================] - 0s 2ms/step
# 0f #3r 5|5+3r5 5|++|^6 )0w^ ]u5+ 83#|^) y0u  w#0 |5 v3ry 9r3++y  4^) |
# 3/3 [==============================] - 0s 2ms/step
# )4r3 54y v3ry 46r334813  )0 13+ m3 45k my 94r+^3r +0 |^+r0)u<3 y0u
# 3/3 [==============================] - 0s 3ms/step
#  w#|<# )0 y0u m34^   4^) +ur^|^6 r0u^) #3 100k3) f0r 4 m0m3^+ 4+
# 3/3 [==============================] - 0s 2ms/step
# 31|7483+#  +|11 <4+<#|^6 #3r 3y3  #3 w|+#)r3w #|5 0w^ 4^) <01)1y 54|)
# 3/3 [==============================] - 0s 2ms/step
#  5#3 |5 +013r4813  8u+ ^0+ #4^)50m3 3^0u6# +0 +3m9+  m3   | 4m |^ ^0
# 3/3 [==============================] - 0s 2ms/step
# #um0ur 4+ 9r353^+ +0 6|v3 <0^53&u3^<3 +0 y0u^6 14)|35 w#0 4r3 51|6#+3)
# 3/3 [==============================] - 0s 3ms/step
# 8y 0+#3r m3^  y0u #4) 83++3r r3+ur^ +0 y0ur 94r+^3r 4^) 3^]0y #3r
# 2/2 [==============================] - 0s 2ms/step
# 5m|135  f0r y0u 4r3 w45+|^6 y0ur +|m3 w|+# m3
# 3/3 [==============================] - 0s 2ms/step
# mr  8|^613y f0110w3) #|5 4)v|<3  mr  )4r<y w41k3) 0ff  4^) 31|7483+#
# 3/3 [==============================] - 0s 2ms/step
# r3m4|^3) w|+# ^0 v3ry <0r)|41 f331|^65 +0w4r) #|m  5#3 +01) +#3 5+0ry
# 3/3 [==============================] - 0s 2ms/step
# #0w3v3r  w|+# 6r34+ 59|r|+ 4m0^6 #3r fr|3^)5  f0r 5#3 #4) 4 1|v31y
# 2/2 [==============================] - 0s 4ms/step
# 914yfu1 )|5905|+|0^  w#|<# )31|6#+3) |^ 4^y+#|^6 r|)|<u10u5
# 3/3 [==============================] - 0s 2ms/step
# +#3 3v3^|^6 41+063+#3r 94553) 0ff 913454^+1y +0 +#3 w#013 f4m|1y  mr5
# 3/3 [==============================] - 0s 2ms/step
# 83^^3+ #4) 533^ #3r 31)35+ )4u6#+3r mu<# 4)m|r3) 8y +#3 ^3+#3rf|31)
# 2/2 [==============================] - 0s 4ms/step
# 94r+y  mr  8|^613y #4) )4^<3) w|+# #3r +w|<3  4^) 5#3 #4) 833^
# 3/3 [==============================] - 0s 2ms/step
# )|5+|^6u|5#3) 8y #|5 5|5+3r5  ]4^3 w45 45 mu<# 6r4+|f|3) 8y +#|5 45
# 3/3 [==============================] - 0s 2ms/step
# #3r m0+#3r <0u1) 83  +#0u6# |^ 4 &u|3+3r w4y  31|7483+# f31+ ]4^3 5
# 3/3 [==============================] - 0s 2ms/step
# 91345ur3  m4ry #4) #34r) #3r531f m3^+|0^3) +0 m|55 8|^613y 45 +#3 m05+
# 3/3 [==============================] - 0s 3ms/step
# 4<<0m91|5#3) 6|r1 |^ +#3 ^3|6#80ur#00)  4^) <4+#3r|^3 4^) 1y)|4 #4) 833^
# 3/3 [==============================] - 0s 5ms/step
# f0r+u^4+3 3^0u6# ^3v3r +0 83 w|+#0u+ 94r+^3r5  w#|<# w45 411 +#4+ +#3y
# 3/3 [==============================] - 0s 3ms/step
# #4) y3+ 134r^+ +0 <4r3 f0r 4+ 4 8411  +#3y r3+ur^3)  +#3r3f0r3  |^ 600)
# 3/3 [==============================] - 0s 3ms/step
# 59|r|+5 +0 10^680ur^  +#3 v|11463 w#3r3 +#3y 1|v3)  4^) 0f w#|<# +#3y
# 3/3 [==============================] - 0s 2ms/step
# w3r3 +#3 9r|^<|941 |^#48|+4^+5  +#3y f0u^) mr  83^^3+ 5+|11 u9  w|+#
# 3/3 [==============================] - 0s 2ms/step
# 4 800k #3 w45 r364r)1355 0f +|m3  4^) 0^ +#3 9r353^+ 0<<45|0^ #3 #4) 4
# 3/3 [==============================] - 0s 2ms/step
# 600) )341 0f <ur|05|+y 45 +0 +#3 3v3^+ 0f 4^ 3v3^|^6 w#|<# #4) r4|53)
# 3/3 [==============================] - 0s 2ms/step
# 5u<# 5913^)|) 3x93<+4+|0^5  #3 #4) r4+#3r #093) +#4+ #|5 w|f3 5 v|3w5 0^
# 3/3 [==============================] - 0s 2ms/step
# +#3 5+r4^63r w0u1) 83 )|54990|^+3)  8u+ #3 500^ f0u^) 0u+ +#4+ #3 #4) 4
# 1/1 [==============================] - 0s 11ms/step
# )|ff3r3^+ 5+0ry +0 #34r
# 3/3 [==============================] - 0s 2ms/step
#  0#  my )34r mr  83^^3+   45 5#3 3^+3r3) +#3 r00m   w3 #4v3 #4) 4 m05+
# 3/3 [==============================] - 0s 2ms/step
# )31|6#+fu1 3v3^|^6  4 m05+ 3x<3113^+ 8411  | w|5# y0u #4) 833^ +#3r3
# 3/3 [==============================] - 0s 2ms/step
# ]4^3 w45 50 4)m|r3)  ^0+#|^6 <0u1) 83 1|k3 |+  3v3ry80)y 54|) #0w w311
# 3/3 [==============================] - 0s 2ms/step
# 5#3 100k3)  4^) mr  8|^613y +#0u6#+ #3r &u|+3 834u+|fu1  4^) )4^<3) w|+#
# 3/3 [==============================] - 0s 2ms/step
# #3r +w|<3  0^1y +#|^k 0f  +#4+   my )34r  #3 4<+u411y )4^<3) w|+# #3r
# 3/3 [==============================] - 0s 2ms/step
# +w|<3  4^) 5#3 w45 +#3 0^1y <r34+ur3 |^ +#3 r00m +#4+ #3 45k3) 4 53<0^)
# 3/3 [==============================] - 0s 2ms/step
# +|m3  f|r5+ 0f 411  #3 45k3) m|55 1u<45  | w45 50 v3x3) +0 533 #|m 5+4^)
# 3/3 [==============================] - 0s 2ms/step
# u9 w|+# #3r  8u+  #0w3v3r  #3 )|) ^0+ 4)m|r3 #3r 4+ 411  |^)33)  ^080)y
# 3/3 [==============================] - 0s 2ms/step
# <4^  y0u k^0w  4^) #3 533m3) &u|+3 5+ru<k w|+# ]4^3 45 5#3 w45 60|^6
# 3/3 [==============================] - 0s 3ms/step
# )0w^ +#3 )4^<3  50 #3 |^&u|r3) w#0 5#3 w45  4^) 60+ |^+r0)u<3)  4^)
# 3/3 [==============================] - 0s 2ms/step
# 45k3) #3r f0r +#3 +w0 ^3x+  +#3^ +#3 +w0 +#|r) #3 )4^<3) w|+# m|55 k|^6
# 3/3 [==============================] - 0s 2ms/step
# 4^) +#3 +w0 f0ur+# w|+# m4r|4 1u<45  4^) +#3 +w0 f|f+# w|+# ]4^3 464|^
# 2/2 [==============================] - 0s 5ms/step
# 4^) +#3 +w0 5|x+# w|+# 1|77y  4^) +#3  80u14^63r
# 3/3 [==============================] - 0s 2ms/step
#  |f #3 #4) #4) 4^y <0m9455|0^ f0r  m3    <r|3) #3r #u584^) |m94+|3^+1y
# 3/3 [==============================] - 0s 2ms/step
#  #3 w0u1) ^0+ #4v3 )4^<3) #41f 50 mu<#  f0r 60) 5 54k3  54y ^0 m0r3 0f
# 3/3 [==============================] - 0s 3ms/step
# #|5 94r+^3r5  0# +#4+ #3 #4) 59r4|^3) #|5 4^k13 |^ +#3 f|r5+ )4^<3
# 3/3 [==============================] - 0s 2ms/step
#  0#  my )34r  | 4m &u|+3 )31|6#+3) w|+# #|m  #3 |5 50 3x<355|v31y
# 3/3 [==============================] - 0s 2ms/step
# #4^)50m3  4^) #|5 5|5+3r5 4r3 <#4rm|^6 w0m3^  | ^3v3r |^ my 1|f3 54w
# 3/3 [==============================] - 0s 2ms/step
# 4^y+#|^6 m0r3 31364^+ +#4^ +#3|r )r35535  | )4r3 54y +#3 14<3 u90^ mr5
# 1/1 [==============================] - 0s 11ms/step
# #ur5+ 5 60w^
# 3/3 [==============================] - 0s 2ms/step
# #3r3 5#3 w45 |^+3rru9+3) 464|^  mr  83^^3+ 9r0+35+3) 464|^5+ 4^y
# 3/3 [==============================] - 0s 2ms/step
# )35<r|9+|0^ 0f f|^3ry  5#3 w45 +#3r3f0r3 081|63) +0 533k 4^0+#3r 8r4^<#
# 3/3 [==============================] - 0s 2ms/step
# 0f +#3 5u8]3<+  4^) r314+3)  w|+# mu<# 8|++3r^355 0f 59|r|+ 4^) 50m3
# 2/2 [==============================] - 0s 5ms/step
# 3x4663r4+|0^  +#3 5#0<k|^6 ru)3^355 0f mr  )4r<y
# 3/3 [==============================] - 0s 2ms/step
#  8u+ | <4^ 455ur3 y0u   5#3 4))3)   +#4+ 1|77y )035 ^0+ 1053 mu<# 8y ^0+
# 3/3 [==============================] - 0s 2ms/step
# 5u|+|^6  #|5  f4^<y  f0r #3 |5 4 m05+ )|546r334813  #0rr|) m4^  ^0+ 4+
# 3/3 [==============================] - 0s 2ms/step
# 411 w0r+# 91345|^6  50 #|6# 4^) 50 <0^<3|+3) +#4+ +#3r3 w45 ^0 3^)ur|^6
# 3/3 [==============================] - 0s 3ms/step
# #|m  #3 w41k3) #3r3  4^) #3 w41k3) +#3r3  f4^<y|^6 #|m531f 50 v3ry
# 3/3 [==============================] - 0s 2ms/step
# 6r34+  ^0+ #4^)50m3 3^0u6# +0 )4^<3 w|+#  | w|5# y0u #4) 833^ +#3r3  my
# 3/3 [==============================] - 0s 2ms/step
# )34r  +0 #4v3 6|v3^ #|m 0^3 0f y0ur 53+ )0w^5  | &u|+3 )3+35+ +#3 m4^
# 1/1 [==============================] - 0s 11ms/step
# <#49+3r
# 3/3 [==============================] - 0s 2ms/step
# w#3^ ]4^3 4^) 31|7483+# w3r3 410^3  +#3 f0rm3r  w#0 #4) 833^ <4u+|0u5 |^
# 3/3 [==============================] - 0s 2ms/step
# #3r 9r4|53 0f mr  8|^613y 83f0r3  3x9r3553) +0 #3r 5|5+3r ]u5+ #0w v3ry
# 1/1 [==============================] - 0s 10ms/step
# mu<# 5#3 4)m|r3) #|m
# 2/2 [==============================] - 0s 2ms/step
#  #3 |5 ]u5+ w#4+ 4 y0u^6 m4^ 0u6#+ +0 83   54|) 5#3   53^5|813
# 3/3 [==============================] - 0s 2ms/step
# 600) #um0ur3)  1|v31y  4^) | ^3v3r 54w 5u<# #499y m4^^3r5   50 mu<#
# 2/2 [==============================] - 0s 2ms/step
# 3453  w|+# 5u<# 93rf3<+ 600) 8r33)|^6
# 3/3 [==============================] - 0s 2ms/step
#  #3 |5 4150 #4^)50m3   r391|3) 31|7483+#   w#|<# 4 y0u^6 m4^ 0u6#+
# 3/3 [==============================] - 0s 2ms/step
# 1|k3w|53 +0 83  |f #3 9055|81y <4^  #|5 <#4r4<+3r |5 +#3r38y <0m913+3
# 3/3 [==============================] - 0s 2ms/step
#  | w45 v3ry mu<# f14++3r3) 8y #|5 45k|^6 m3 +0 )4^<3 4 53<0^) +|m3  |
# 2/2 [==============================] - 0s 2ms/step
# )|) ^0+ 3x93<+ 5u<# 4 <0m91|m3^+
# 3/3 [==============================] - 0s 2ms/step
#  )|) ^0+ y0u  | )|) f0r y0u  8u+ +#4+ |5 0^3 6r34+ )|ff3r3^<3 83+w33^
# 3/3 [==============================] - 0s 2ms/step
# u5  <0m91|m3^+5 41w4y5 +4k3  y0u  8y 5ur9r|53  4^)  m3  ^3v3r  w#4+
# 3/3 [==============================] - 0s 2ms/step
# <0u1) 83 m0r3 ^4+ur41 +#4^ #|5 45k|^6 y0u 464|^  #3 <0u1) ^0+ #319
# 3/3 [==============================] - 0s 2ms/step
# 533|^6 +#4+ y0u w3r3 480u+ f|v3 +|m35 45 9r3++y 45 3v3ry 0+#3r w0m4^
# 3/3 [==============================] - 0s 2ms/step
# |^ +#3 r00m  ^0 +#4^k5 +0 #|5 64114^+ry f0r +#4+  w311  #3 <3r+4|^1y |5
# 3/3 [==============================] - 0s 2ms/step
# v3ry 46r334813  4^) | 6|v3 y0u 134v3 +0 1|k3 #|m  y0u #4v3 1|k3) m4^y 4
# 1/1 [==============================] - 0s 9ms/step
# 5+u9|)3r 93r50^
# 1/1 [==============================] - 0s 11ms/step
#  )34r 1|77y
# 3/3 [==============================] - 0s 2ms/step
#  0#  y0u 4r3 4 6r34+ )341 +00 49+  y0u k^0w  +0 1|k3 930913 |^ 63^3r41
# 3/3 [==============================] - 0s 2ms/step
# y0u ^3v3r 533 4 f4u1+ |^ 4^y80)y  411 +#3 w0r1) 4r3 600) 4^) 46r334813
# 3/3 [==============================] - 0s 2ms/step
# |^ y0ur 3y35  | ^3v3r #34r) y0u 5934k |11 0f 4 #um4^ 83|^6 |^ y0ur
# 1/1 [==============================] - 0s 10ms/step
# 1|f3
# 3/3 [==============================] - 0s 2ms/step
#  | w0u1) ^0+ w|5# +0 83 #45+y |^ <3^5ur|^6 4^y0^3  8u+ | 41w4y5 5934k
# 1/1 [==============================] - 0s 11ms/step
# w#4+ | +#|^k
# 3/3 [==============================] - 0s 2ms/step
#  | k^0w y0u )0  4^) |+ |5  +#4+  w#|<# m4k35 +#3 w0^)3r  w|+#  y0ur
# 3/3 [==============================] - 0s 2ms/step
# 600) 53^53  +0 83 50 #0^35+1y 81|^) +0 +#3 f011|35 4^) ^0^53^53 0f
# 3/3 [==============================] - 0s 2ms/step
# 0+#3r5  4ff3<+4+|0^ 0f <4^)0ur |5 <0mm0^ 3^0u6#  0^3 m33+5 w|+# |+
# 3/3 [==============================] - 0s 2ms/step
# 3v3ryw#3r3  8u+ +0 83 <4^)|) w|+#0u+ 05+3^+4+|0^ 0r )35|6^  +0 +4k3 +#3
# 3/3 [==============================] - 0s 2ms/step
# 600) 0f 3v3ry80)y 5 <#4r4<+3r 4^) m4k3 |+ 5+|11 83++3r  4^) 54y ^0+#|^6
# 3/3 [==============================] - 0s 2ms/step
# 0f +#3 84)  8310^65 +0 y0u 410^3  4^) 50 y0u 1|k3 +#|5 m4^ 5 5|5+3r5
# 2/2 [==============================] - 0s 2ms/step
# +00  )0 y0u  +#3|r m4^^3r5 4r3 ^0+ 3&u41 +0 #|5
# 3/3 [==============================] - 0s 2ms/step
#  <3r+4|^1y ^0+  4+ f|r5+  8u+ +#3y 4r3 v3ry 91345|^6 w0m3^ w#3^ y0u
# 3/3 [==============================] - 0s 2ms/step
# <0^v3r53 w|+# +#3m  m|55 8|^613y |5 +0 1|v3 w|+# #3r 8r0+#3r  4^) k339
# 3/3 [==============================] - 0s 2ms/step
# #|5 #0u53  4^) | 4m mu<# m|5+4k3^ |f w3 5#411 ^0+ f|^) 4 v3ry <#4rm|^6
# 1/1 [==============================] - 0s 12ms/step
# ^3|6#80ur |^ #3r
# 3/3 [==============================] - 0s 3ms/step
# ...
# 3/3 [==============================] - 0s 3ms/step
# 80+# +#3 9r0]3<+ 6u+3^83r6 1|+3r4ry 4r<#|v3 f0u^)4+|0^ 4^) m|<#431
# 3/3 [==============================] - 0s 2ms/step
# #4r+  +#3 0w^3r 0f +#3 9r0]3<+ 6u+3^83r6 +m +r4)3m4rk   <0^+4<+ +#3
# 2/2 [==============================] - 0s 4ms/step
# f0u^)4+|0^ 45 53+ f0r+# |^ 53<+|0^   8310w
# 1/1 [==============================] - 0s 8ms/step
#   f
# 3/3 [==============================] - 0s 3ms/step
#   f     9r0]3<+ 6u+3^83r6 v01u^+33r5 4^) 3m910y335 3x93^) <0^5|)3r4813
# 3/3 [==============================] - 0s 2ms/step
# 3ff0r+ +0 |)3^+|fy  )0 <09yr|6#+ r3534r<# 0^  +r4^5<r|83 4^) 9r00fr34)
# 2/2 [==============================] - 0s 2ms/step
# 9u81|< )0m4|^ w0rk5 |^ <r34+|^6 +#3 9r0]3<+ 6u+3^83r6 +m
# 3/3 [==============================] - 0s 2ms/step
# <0113<+|0^   )359|+3 +#353 3ff0r+5  9r0]3<+ 6u+3^83r6 +m 313<+r0^|<
# 2/2 [==============================] - 0s 4ms/step
# w0rk5  4^) +#3 m3)|um 0^ w#|<# +#3y m4y 83 5+0r3)  m4y <0^+4|^
# 3/3 [==============================] - 0s 3ms/step
#  )3f3<+5   5u<# 45  8u+ ^0+ 1|m|+3) +0  |^<0m913+3  |^4<<ur4+3 0r
# 3/3 [==============================] - 0s 2ms/step
# <0rru9+ )4+4  +r4^5<r|9+|0^ 3rr0r5  4 <09yr|6#+ 0r 0+#3r |^+3113<+u41
# 3/3 [==============================] - 0s 2ms/step
# 9r093r+y |^fr|^63m3^+  4 )3f3<+|v3 0r )4m463) )|5k 0r 0+#3r m3)|um  4
# 3/3 [==============================] - 0s 1ms/step
# <0m9u+3r v|ru5  0r <0m9u+3r <0)35 +#4+ )4m463 0r <4^^0+ 83 r34) 8y
# 1/1 [==============================] - 0s 10ms/step
# y0ur 3&u|9m3^+
# 3/3 [==============================] - 0s 2ms/step
#   f     1|m|+3) w4rr4^+y  )|5<14|m3r 0f )4m4635   3x<39+ f0r +#3  r|6#+
# 3/3 [==============================] - 0s 2ms/step
# 0f r3914<3m3^+ 0r r3fu^)  )35<r|83) |^ 94r46r49#   f    +#3 9r0]3<+
# 2/2 [==============================] - 0s 2ms/step
# 6u+3^83r6 1|+3r4ry 4r<#|v3 f0u^)4+|0^  +#3 0w^3r 0f +#3 9r0]3<+
# 3/3 [==============================] - 0s 2ms/step
# 6u+3^83r6 +m +r4)3m4rk  4^) 4^y 0+#3r 94r+y )|5+r|8u+|^6 4 9r0]3<+
# 2/2 [==============================] - 0s 2ms/step
# 6u+3^83r6 +m 313<+r0^|< w0rk u^)3r +#|5 46r33m3^+  )|5<14|m 411
# 3/3 [==============================] - 0s 2ms/step
# 1|48|1|+y +0 y0u f0r )4m4635  <05+5 4^) 3x93^535  |^<1u)|^6 13641
# 3/3 [==============================] - 0s 2ms/step
# f335   y0u 46r33 +#4+ y0u #4v3 ^0 r3m3)|35 f0r ^361|63^<3  5+r|<+
# 3/3 [==============================] - 0s 2ms/step
# 1|48|1|+y  8r34<# 0f w4rr4^+y 0r 8r34<# 0f <0^+r4<+ 3x<39+ +#053
# 2/2 [==============================] - 0s 4ms/step
# 9r0v|)3) |^ 94r46r49# f    y0u 46r33 +#4+ +#3 f0u^)4+|0^  +#3
# 3/3 [==============================] - 0s 2ms/step
# +r4)3m4rk 0w^3r  4^) 4^y )|5+r|8u+0r u^)3r +#|5 46r33m3^+ w|11 ^0+ 83
# 3/3 [==============================] - 0s 2ms/step
# 1|4813 +0 y0u f0r 4<+u41  )|r3<+  |^)|r3<+  <0^53&u3^+|41  9u^|+|v3 0r
# 3/3 [==============================] - 0s 2ms/step
# |^<|)3^+41 )4m4635 3v3^ |f y0u 6|v3 ^0+|<3 0f +#3 9055|8|1|+y 0f 5u<#
# 1/1 [==============================] - 0s 8ms/step
# )4m463
# 3/3 [==============================] - 0s 2ms/step
#   f     1|m|+3) r|6#+ 0f r3914<3m3^+ 0r r3fu^)   |f y0u )|5<0v3r 4
# 3/3 [==============================] - 0s 2ms/step
# )3f3<+ |^ +#|5 313<+r0^|< w0rk w|+#|^    )4y5 0f r3<3|v|^6 |+  y0u <4^
# 3/3 [==============================] - 0s 2ms/step
# r3<3|v3 4 r3fu^) 0f +#3 m0^3y  |f 4^y  y0u 94|) f0r |+ 8y 53^)|^6 4
# 3/3 [==============================] - 0s 1ms/step
# wr|++3^ 3x914^4+|0^ +0 +#3 93r50^ y0u r3<3|v3) +#3 w0rk fr0m   |f y0u
# 3/3 [==============================] - 0s 2ms/step
# r3<3|v3) +#3 w0rk 0^ 4 9#y5|<41 m3)|um  y0u mu5+ r3+ur^ +#3 m3)|um w|+#
# 3/3 [==============================] - 0s 2ms/step
# y0ur wr|++3^ 3x914^4+|0^   +#3 93r50^ 0r 3^+|+y +#4+ 9r0v|)3) y0u w|+#
# 3/3 [==============================] - 0s 2ms/step
# +#3 )3f3<+|v3 w0rk m4y 313<+ +0 9r0v|)3 4 r3914<3m3^+ <09y |^ 1|3u 0f 4
# 3/3 [==============================] - 0s 2ms/step
# r3fu^)   |f y0u r3<3|v3) +#3 w0rk 313<+r0^|<411y  +#3 93r50^ 0r 3^+|+y
# 3/3 [==============================] - 0s 2ms/step
# 9r0v|)|^6 |+ +0 y0u m4y <#0053 +0 6|v3 y0u 4 53<0^) 0990r+u^|+y +0
# 3/3 [==============================] - 0s 2ms/step
# r3<3|v3 +#3 w0rk 313<+r0^|<411y |^ 1|3u 0f 4 r3fu^)   |f +#3 53<0^) <09y
# 3/3 [==============================] - 0s 2ms/step
# |5 4150 )3f3<+|v3  y0u m4y )3m4^) 4 r3fu^) |^ wr|+|^6 w|+#0u+ fur+#3r
# 2/2 [==============================] - 0s 2ms/step
# 0990r+u^|+|35 +0 f|x +#3 9r0813m
# 3/3 [==============================] - 0s 2ms/step
#   f     3x<39+ f0r +#3 1|m|+3) r|6#+ 0f r3914<3m3^+ 0r r3fu^) 53+ f0r+#
# 3/3 [==============================] - 0s 2ms/step
# |^ 94r46r49#   f    +#|5 w0rk |5 9r0v|)3) +0 y0u  45 |5  w|+# ^0 0+#3r
# 3/3 [==============================] - 0s 2ms/step
# w4rr4^+|35 0f 4^y k|^)  3x9r355 0r |m91|3)  |^<1u)|^6 8u+ ^0+ 1|m|+3) +0
# 2/2 [==============================] - 0s 4ms/step
# w4rr4^+|35 0f m3r<#4^+|8|1|+y 0r f|+^355 f0r 4^y 9ur9053
# 2/2 [==============================] - 0s 2ms/step
#   f     50m3 5+4+35 )0 ^0+ 4110w )|5<14|m3r5 0f <3r+4|^ |m91|3)
# 3/3 [==============================] - 0s 2ms/step
# w4rr4^+|35 0r +#3 3x<1u5|0^ 0r 1|m|+4+|0^ 0f <3r+4|^ +y935 0f )4m4635
# 3/3 [==============================] - 0s 3ms/step
# |f 4^y )|5<14|m3r 0r 1|m|+4+|0^ 53+ f0r+# |^ +#|5 46r33m3^+ v|014+35 +#3
# 3/3 [==============================] - 0s 2ms/step
# 14w 0f +#3 5+4+3 4991|<4813 +0 +#|5 46r33m3^+  +#3 46r33m3^+ 5#411 83
# 3/3 [==============================] - 0s 2ms/step
# |^+3r9r3+3) +0 m4k3 +#3 m4x|mum )|5<14|m3r 0r 1|m|+4+|0^ 93rm|++3) 8y
# 3/3 [==============================] - 0s 3ms/step
# +#3 4991|<4813 5+4+3 14w   +#3 |^v41|)|+y 0r u^3^f0r<348|1|+y 0f 4^y
# 3/3 [==============================] - 0s 2ms/step
# 9r0v|5|0^ 0f +#|5 46r33m3^+ 5#411 ^0+ v0|) +#3 r3m4|^|^6 9r0v|5|0^5
# 3/3 [==============================] - 0s 2ms/step
#   f     |^)3m^|+y   y0u 46r33 +0 |^)3m^|fy 4^) #01) +#3 f0u^)4+|0^  +#3
# 3/3 [==============================] - 0s 2ms/step
# +r4)3m4rk 0w^3r  4^y 463^+ 0r 3m910y33 0f +#3 f0u^)4+|0^  4^y0^3
# 3/3 [==============================] - 0s 2ms/step
# 9r0v|)|^6 <09|35 0f 9r0]3<+ 6u+3^83r6 +m 313<+r0^|< w0rk5 |^ 4<<0r)4^<3
# 3/3 [==============================] - 0s 2ms/step
# w|+# +#|5 46r33m3^+  4^) 4^y v01u^+33r5 4550<|4+3) w|+# +#3 9r0)u<+|0^
# 3/3 [==============================] - 0s 2ms/step
# 9r0m0+|0^ 4^) )|5+r|8u+|0^ 0f 9r0]3<+ 6u+3^83r6 +m 313<+r0^|< w0rk5
# 3/3 [==============================] - 0s 2ms/step
# #4rm1355 fr0m 411 1|48|1|+y  <05+5 4^) 3x93^535  |^<1u)|^6 13641 f335
# 3/3 [==============================] - 0s 2ms/step
# +#4+ 4r|53 )|r3<+1y 0r |^)|r3<+1y fr0m 4^y 0f +#3 f0110w|^6 w#|<# y0u )0
# 3/3 [==============================] - 0s 2ms/step
# 0r <4u53 +0 0<<ur   4  )|5+r|8u+|0^ 0f +#|5 0r 4^y 9r0]3<+ 6u+3^83r6 +m
# 3/3 [==============================] - 0s 2ms/step
# w0rk   8  41+3r4+|0^  m0)|f|<4+|0^  0r 4))|+|0^5 0r )313+|0^5 +0 4^y
# 2/2 [==============================] - 0s 2ms/step
# 9r0]3<+ 6u+3^83r6 +m w0rk  4^)  <  4^y )3f3<+ y0u <4u53
# 3/3 [==============================] - 0s 2ms/step
# 53<+|0^      |^f0rm4+|0^ 480u+ +#3 m|55|0^ 0f 9r0]3<+ 6u+3^83r6 +m
# 3/3 [==============================] - 0s 2ms/step
# 9r0]3<+ 6u+3^83r6 +m |5 5y^0^ym0u5 w|+# +#3 fr33 )|5+r|8u+|0^ 0f
# 3/3 [==============================] - 0s 2ms/step
# 313<+r0^|< w0rk5 |^ f0rm4+5 r34)4813 8y +#3 w|)35+ v4r|3+y 0f <0m9u+3r5
# 3/3 [==============================] - 0s 1ms/step
# |^<1u)|^6 085013+3  01)  m|))13 463) 4^) ^3w <0m9u+3r5   |+ 3x|5+5
# 3/3 [==============================] - 0s 2ms/step
# 83<4u53 0f +#3 3ff0r+5 0f #u^)r3)5 0f v01u^+33r5 4^) )0^4+|0^5 fr0m
# 1/1 [==============================] - 0s 10ms/step
# 930913 |^ 411 w41k5 0f 1|f3
# 2/2 [==============================] - 0s 2ms/step
# v01u^+33r5 4^) f|^4^<|41 5u990r+ +0 9r0v|)3 v01u^+33r5 w|+# +#3
# 3/3 [==============================] - 0s 3ms/step
# 455|5+4^<3 +#3y ^33)  4r3 <r|+|<41 +0 r34<#|^6 9r0]3<+ 6u+3^83r6 +m 5
# 3/3 [==============================] - 0s 3ms/step
# 60415 4^) 3^5ur|^6 +#4+ +#3 9r0]3<+ 6u+3^83r6 +m <0113<+|0^ w|11
# 3/3 [==============================] - 0s 2ms/step
# r3m4|^ fr331y 4v4|14813 f0r 63^3r4+|0^5 +0 <0m3   |^       +#3 9r0]3<+
# 3/3 [==============================] - 0s 2ms/step
# 6u+3^83r6 1|+3r4ry 4r<#|v3 f0u^)4+|0^ w45 <r34+3) +0 9r0v|)3 4 53<ur3
# 3/3 [==============================] - 0s 2ms/step
# 4^) 93rm4^3^+ fu+ur3 f0r 9r0]3<+ 6u+3^83r6 +m 4^) fu+ur3 63^3r4+|0^5
# 3/3 [==============================] - 0s 2ms/step
# +0 134r^ m0r3 480u+ +#3 9r0]3<+ 6u+3^83r6 1|+3r4ry 4r<#|v3 f0u^)4+|0^
# 3/3 [==============================] - 0s 2ms/step
# 4^) #0w y0ur 3ff0r+5 4^) )0^4+|0^5 <4^ #319  533 53<+|0^5   4^)
# 2/2 [==============================] - 0s 4ms/step
# 4^) +#3 f0u^)4+|0^ w38 9463 4+ #++9   www 9614f 0r6
# 3/3 [==============================] - 0s 2ms/step
# 53<+|0^     |^f0rm4+|0^ 480u+ +#3 9r0]3<+ 6u+3^83r6 1|+3r4ry 4r<#|v3
# 1/1 [==============================] - 0s 10ms/step
# f0u^)4+|0^
# 3/3 [==============================] - 0s 2ms/step
# +#3 9r0]3<+ 6u+3^83r6 1|+3r4ry 4r<#|v3 f0u^)4+|0^ |5 4 ^0^ 9r0f|+
# 3/3 [==============================] - 0s 2ms/step
#     <     3)u<4+|0^41 <0r90r4+|0^ 0r64^|73) u^)3r +#3 14w5 0f +#3
# 3/3 [==============================] - 0s 3ms/step
# 5+4+3 0f m|55|55|99| 4^) 6r4^+3) +4x 3x3m9+ 5+4+u5 8y +#3 |^+3r^41
# 3/3 [==============================] - 0s 2ms/step
# r3v3^u3 53rv|<3   +#3 f0u^)4+|0^ 5 3|^ 0r f3)3r41 +4x |)3^+|f|<4+|0^
# 2/2 [==============================] - 0s 4ms/step
# ^um83r |5              |+5     <     13++3r |5 905+3) 4+
# 3/3 [==============================] - 0s 2ms/step
# #++9   9614f 0r6 fu^)r4|5|^6   <0^+r|8u+|0^5 +0 +#3 9r0]3<+ 6u+3^83r6
# 3/3 [==============================] - 0s 2ms/step
# 1|+3r4ry 4r<#|v3 f0u^)4+|0^ 4r3 +4x )3)u<+|813 +0 +#3 fu11 3x+3^+
# 2/2 [==============================] - 0s 4ms/step
# 93rm|++3) 8y u 5  f3)3r41 14w5 4^) y0ur 5+4+3 5 14w5
# 3/3 [==============================] - 0s 2ms/step
# +#3 f0u^)4+|0^ 5 9r|^<|941 0ff|<3 |5 10<4+3) 4+      m314^ )r  5
# 3/3 [==============================] - 0s 2ms/step
# f4|r84^k5  4k          8u+ |+5 v01u^+33r5 4^) 3m910y335 4r3 5<4++3r3)
# 3/3 [==============================] - 0s 2ms/step
# +#r0u6#0u+ ^um3r0u5 10<4+|0^5   |+5 8u5|^355 0ff|<3 |5 10<4+3) 4+
# 3/3 [==============================] - 0s 2ms/step
#     ^0r+#      w35+  541+ 14k3 <|+y  u+                        3m4|1
# 2/2 [==============================] - 0s 2ms/step
# 8u5|^355 9614f 0r6   3m4|1 <0^+4<+ 1|^k5 4^) u9 +0 )4+3 <0^+4<+
# 3/3 [==============================] - 0s 2ms/step
# |^f0rm4+|0^ <4^ 83 f0u^) 4+ +#3 f0u^)4+|0^ 5 w38 5|+3 4^) 0ff|<|41
# 1/1 [==============================] - 0s 8ms/step
# 9463 4+ #++9   9614f 0r6
# 2/2 [==============================] - 0s 4ms/step
# f0r 4))|+|0^41 <0^+4<+ |^f0rm4+|0^
# 1/1 [==============================] - 0s 8ms/step
#      )r  6r360ry 8  ^3w8y
# 2/2 [==============================] - 0s 5ms/step
#      <#|3f 3x3<u+|v3 4^) )|r3<+0r
# 1/1 [==============================] - 0s 10ms/step
#      68^3w8y 9614f 0r6
# 3/3 [==============================] - 0s 2ms/step
# 53<+|0^     |^f0rm4+|0^ 480u+ )0^4+|0^5 +0 +#3 9r0]3<+ 6u+3^83r6
# 1/1 [==============================] - 0s 10ms/step
# 1|+3r4ry 4r<#|v3 f0u^)4+|0^
# 3/3 [==============================] - 0s 2ms/step
# 9r0]3<+ 6u+3^83r6 +m )393^)5 u90^ 4^) <4^^0+ 5urv|v3 w|+#0u+ w|)3
# 2/2 [==============================] - 0s 2ms/step
# 59r34) 9u81|< 5u990r+ 4^) )0^4+|0^5 +0 <4rry 0u+ |+5 m|55|0^ 0f
# 3/3 [==============================] - 0s 2ms/step
# |^<r345|^6 +#3 ^um83r 0f 9u81|< )0m4|^ 4^) 1|<3^53) w0rk5 +#4+ <4^ 83
# 3/3 [==============================] - 0s 2ms/step
# fr331y )|5+r|8u+3) |^ m4<#|^3 r34)4813 f0rm 4<<355|813 8y +#3 w|)35+
# 3/3 [==============================] - 0s 3ms/step
# 4rr4y 0f 3&u|9m3^+ |^<1u)|^6 0u+)4+3) 3&u|9m3^+   m4^y 5m411 )0^4+|0^5
# 3/3 [==============================] - 0s 2ms/step
#     +0         4r3 94r+|<u14r1y |m90r+4^+ +0 m4|^+4|^|^6 +4x 3x3m9+
# 1/1 [==============================] - 0s 8ms/step
# 5+4+u5 w|+# +#3 |r5
# 3/3 [==============================] - 0s 2ms/step
# +#3 f0u^)4+|0^ |5 <0mm|++3) +0 <0m91y|^6 w|+# +#3 14w5 r36u14+|^6
# 3/3 [==============================] - 0s 2ms/step
# <#4r|+|35 4^) <#4r|+4813 )0^4+|0^5 |^ 411    5+4+35 0f +#3 u^|+3)
# 2/2 [==============================] - 0s 2ms/step
# 5+4+35   <0m91|4^<3 r3&u|r3m3^+5 4r3 ^0+ u^|f0rm 4^) |+ +4k35 4
# 3/3 [==============================] - 0s 2ms/step
# <0^5|)3r4813 3ff0r+  mu<# 9493rw0rk 4^) m4^y f335 +0 m33+ 4^) k339 u9
# 3/3 [==============================] - 0s 2ms/step
# w|+# +#353 r3&u|r3m3^+5   w3 )0 ^0+ 501|<|+ )0^4+|0^5 |^ 10<4+|0^5
# 3/3 [==============================] - 0s 2ms/step
# w#3r3 w3 #4v3 ^0+ r3<3|v3) wr|++3^ <0^f|rm4+|0^ 0f <0m91|4^<3   +0
# 2/2 [==============================] - 0s 2ms/step
# 53^) )0^4+|0^5 0r )3+3rm|^3 +#3 5+4+u5 0f <0m91|4^<3 f0r 4^y
# 2/2 [==============================] - 0s 4ms/step
# 94r+|<u14r 5+4+3 v|5|+ #++9   9614f 0r6
# 3/3 [==============================] - 0s 2ms/step
# w#|13 w3 <4^^0+ 4^) )0 ^0+ 501|<|+ <0^+r|8u+|0^5 fr0m 5+4+35 w#3r3 w3
# 3/3 [==============================] - 0s 2ms/step
# #4v3 ^0+ m3+ +#3 501|<|+4+|0^ r3&u|r3m3^+5  w3 k^0w 0f ^0 9r0#|8|+|0^
# 3/3 [==============================] - 0s 2ms/step
# 464|^5+ 4<<39+|^6 u^501|<|+3) )0^4+|0^5 fr0m )0^0r5 |^ 5u<# 5+4+35 w#0
# 2/2 [==============================] - 0s 2ms/step
# 499r04<# u5 w|+# 0ff3r5 +0 )0^4+3
# 3/3 [==============================] - 0s 2ms/step
# |^+3r^4+|0^41 )0^4+|0^5 4r3 6r4+3fu11y 4<<39+3)  8u+ w3 <4^^0+ m4k3
# 3/3 [==============================] - 0s 2ms/step
# 4^y 5+4+3m3^+5 <0^<3r^|^6 +4x +r34+m3^+ 0f )0^4+|0^5 r3<3|v3) fr0m
# 3/3 [==============================] - 0s 2ms/step
# 0u+5|)3 +#3 u^|+3) 5+4+35   u 5  14w5 410^3 5w4m9 0ur 5m411 5+4ff
# 3/3 [==============================] - 0s 2ms/step
# 913453 <#3<k +#3 9r0]3<+ 6u+3^83r6 w38 94635 f0r <urr3^+ )0^4+|0^
# 3/3 [==============================] - 0s 2ms/step
# m3+#0)5 4^) 4))r35535   )0^4+|0^5 4r3 4<<39+3) |^ 4 ^um83r 0f 0+#3r
# 3/3 [==============================] - 0s 2ms/step
# w4y5 |^<1u)|^6 <#3<k5  0^1|^3 94ym3^+5 4^) <r3)|+ <4r) )0^4+|0^5
# 2/2 [==============================] - 0s 4ms/step
# +0 )0^4+3  913453 v|5|+  #++9   9614f 0r6 )0^4+3
# 3/3 [==============================] - 0s 2ms/step
# 53<+|0^     63^3r41 |^f0rm4+|0^ 480u+ 9r0]3<+ 6u+3^83r6 +m 313<+r0^|<
# 1/1 [==============================] - 0s 7ms/step
# w0rk5
# 3/3 [==============================] - 0s 2ms/step
# 9r0f3550r m|<#431 5  #4r+ |5 +#3 0r|6|^4+0r 0f +#3 9r0]3<+ 6u+3^83r6 +m
# 3/3 [==============================] - 0s 3ms/step
# <0^<39+ 0f 4 1|8r4ry 0f 313<+r0^|< w0rk5 +#4+ <0u1) 83 fr331y 5#4r3)
# 3/3 [==============================] - 0s 2ms/step
# w|+# 4^y0^3   f0r +#|r+y y34r5  #3 9r0)u<3) 4^) )|5+r|8u+3) 9r0]3<+
# 3/3 [==============================] - 0s 2ms/step
# 6u+3^83r6 +m 3800k5 w|+# 0^1y 4 10053 ^3+w0rk 0f v01u^+33r 5u990r+
# 3/3 [==============================] - 0s 2ms/step
# 9r0]3<+ 6u+3^83r6 +m 3800k5 4r3 0f+3^ <r34+3) fr0m 53v3r41 9r|^+3)
# 3/3 [==============================] - 0s 2ms/step
# 3)|+|0^5  411 0f w#|<# 4r3 <0^f|rm3) 45 9u81|< )0m4|^ |^ +#3 u 5
# 3/3 [==============================] - 0s 2ms/step
# u^1355 4 <09yr|6#+ ^0+|<3 |5 |^<1u)3)   +#u5  w3 )0 ^0+ ^3<3554r|1y
# 2/2 [==============================] - 0s 4ms/step
# k339 3800k5 |^ <0m91|4^<3 w|+# 4^y 94r+|<u14r 9493r 3)|+|0^
# 3/3 [==============================] - 0s 3ms/step
# m05+ 930913 5+4r+ 4+ 0ur w38 5|+3 w#|<# #45 +#3 m4|^ 96 534r<# f4<|1|+y
# 1/1 [==============================] - 0s 11ms/step
#      #++9   www 6u+3^83r6 0r6
# 2/2 [==============================] - 0s 4ms/step
# +#|5 w38 5|+3 |^<1u)35 |^f0rm4+|0^ 480u+ 9r0]3<+ 6u+3^83r6 +m
# 3/3 [==============================] - 0s 2ms/step
# |^<1u)|^6 #0w +0 m4k3 )0^4+|0^5 +0 +#3 9r0]3<+ 6u+3^83r6 1|+3r4ry
# 3/3 [==============================] - 0s 3ms/step
# 4r<#|v3 f0u^)4+|0^  #0w +0 #319 9r0)u<3 0ur ^3w 3800k5  4^) #0w +0
# 2/2 [==============================] - 0s 2ms/step
# 5u85<r|83 +0 0ur 3m4|1 ^3w513++3r +0 #34r 480u+ ^3w 3800k5
# Count: 11032
